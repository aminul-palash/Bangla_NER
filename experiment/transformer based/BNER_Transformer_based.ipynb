# %% [markdown]
# # NER TRAINING WITH ONLY PERSON ENTITY DATASET

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

# Open the JSON file
with open("/content/drive/MyDrive/NER/updated_merged_data.json", "r") as file:
    # Load the JSON data
    dataset = json.load(file)

len(dataset)
# Out:
# 8667

# %%
import random
from spacy.util import minibatch, compounding


# Set the random seed for reproducibility
random.seed(42)

# Shuffle the dataset
random.shuffle(dataset)

# Define the split ratios
train_ratio = 0.8  # 80% for training
val_ratio = 0.1  # 10% for validation
test_ratio = 0.1  # 10% for testing

# Calculate the sizes of each split
total_size = len(dataset)
train_size = int(train_ratio * total_size)
val_size = int(val_ratio * total_size)

# Split the dataset into train, validation, and test sets
train_data = dataset[:train_size]
val_data = dataset[train_size:train_size + val_size]
test_data = dataset[train_size + val_size:]

# Print the sizes of each split
print(f"Training set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Training set size: 6933
# Validation set size: 866
# Test set size: 868

# %%
# !mkdir data

# %%
with open("data/train.json", 'w') as fp:
        json.dump(train_data, fp, indent=2, ensure_ascii=False)


with open("data/test.json", 'w') as fp:
        json.dump(test_data, fp, indent=2, ensure_ascii=False)


with open("data/val.json", 'w') as fp:
        json.dump(val_data, fp, indent=2, ensure_ascii=False)

# %%
# !python -m spacy convert data/train.json ./data
# !python -m spacy convert data/test.json ./data
# !python -m spacy convert data/val.json ./data
# Out:
# 2023-06-28 10:58:11.265765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Generated output file (6933 documents): data/train.spacy
# 2023-06-28 10:58:26.231331: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Generated output file (868 documents): data/test.spacy
# 2023-06-28 10:58:34.177821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Generated output file (866 documents): data/val.spacy

# %%
# !pip install transformers
# !pip install spacy-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 61.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.8/190.8 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 35.6 MB/s eta 0:00:00
# ...

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# 2023-06-28 10:59:05.104748: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./output --paths.train data/train.spacy --paths.dev data/val.spacy --gpu-id 0
# Out:
# 2023-06-28 10:59:11.584290: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Created output directory: output
# ℹ Saving to output directory: output
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2023-06-28 10:59:19,429] [INFO] Set up nlp object from config
# [2023-06-28 10:59:19,484] [INFO] Pipeline: ['transformer', 'ner']
# [2023-06-28 10:59:19,490] [INFO] Created vocabulary
# [2023-06-28 10:59:19,490] [INFO] Finished initializing nlp object
# ...
# Some weights of the model checkpoint at sagorsarker/bangla-bert-base were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# ...

# %%
# !zip -r ./models_multilingual_bert.zip /content/output/model-best
# Out:
#   adding: content/output/model-best/ (stored 0%)
#   adding: content/output/model-best/vocab/ (stored 0%)
#   adding: content/output/model-best/vocab/vectors (deflated 45%)
#   adding: content/output/model-best/vocab/lookups.bin (stored 0%)
#   adding: content/output/model-best/vocab/key2row (stored 0%)
#   adding: content/output/model-best/vocab/vectors.cfg (stored 0%)
#   adding: content/output/model-best/vocab/strings.json (deflated 90%)
#   adding: content/output/model-best/transformer/ (stored 0%)
#   adding: content/output/model-best/transformer/model (deflated 8%)
#   adding: content/output/model-best/transformer/cfg (stored 0%)
#   adding: content/output/model-best/meta.json (deflated 57%)
#   adding: content/output/model-best/ner/ (stored 0%)
#   adding: content/output/model-best/ner/model (deflated 8%)
#   adding: content/output/model-best/ner/moves (deflated 40%)
#   adding: content/output/model-best/ner/cfg (deflated 33%)
# ...

# %%
import spacy_transformers
import spacy

nlp = spacy.load("/content/output/model-best")

text_list = [
    "বিএনপি নেতাদের সবচেয়ে বড় দুর্বলতা তাঁরা রাজনৈতিক কর্মী আর সন্ত্রাসী গুলিয়ে ফেলেছেন বলে মন্তব্য করেছেন তথ্যমন্ত্রী হাছান মাহমুদ",
    "আব্দুর রহিম নামের কাস্টমারকে একশ টাকা বাকি দিলাম",
    "পুতিনের দুর্বলতা ফাঁস করে দিয়েছে ভাগনার",
    "এবার বাবা শাহরুখের ছবিতে অভিনয় করবেন সুহানা",
    "বিনা প্রতিদ্বন্দ্বিতায় বান্দরবান পৌরসভার মেয়র হলেন আওয়ামী লীগের শামসুল",
    "রাত সাড়ে নয়টার দিকে রিটার্নিং কর্মকর্তা ফয়সল কাদের বেসরকারিভাবে আওয়ামী লীগের প্রার্থী মো. আনোয়ারুজ্জামান চৌধুরীকে বিজয়ী ঘোষণা করেন",
    " যাঁরা জায়েদ খানের পারফরম্যান্স দেখতে চান, তাঁরা আগামী দিনে ওয়াশিংটনে গেলে দেখতে পাবেন।"

]
for text in text_list:
    doc = nlp(text)

    print(f"Input: {text}")
    for entity in doc.ents:
        print(f"Entity: {entity.text}, Label: {entity.label_}")
    print("---")

# %%
# !python -m spacy evaluate --help
# Out:
# 2023-06-28 12:32:39.072034: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#  Usage: python -m spacy evaluate
#             [OPTIONS] MODEL DATA_PATH
#
#  Evaluate a trained pipeline. Expects a loadable spaCy pipeline and evaluation
#  data in the binary .spacy format. The --gold-preproc option sets up the
#  evaluation examples with gold-standard sentences and tokens for the
#  predictions. Gold preprocessing helps the annotations align to the
#  tokenization, and may result in sequences of more consistent length. However,
#  it may reduce runtime accuracy due to train/test skew. To render a sample of
#  dependency parses in a HTML file, set as output directory as the displacy_path
#  argument.
#  DOCS: https://spacy.io/api/cli#benchmark-accuracy
#
# ╭─ Arguments ──────────────────────────────────────────────────────────────────╮
# │ *    model          TEXT  Model name or path [default: None] [required]      │
# ...

# %%
import os
# os.mkdir('result')
# !python -m spacy evaluate output/model-best data/test.spacy --gpu-id 0 -dp result
# Out:
# 2023-06-28 12:33:01.225080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   86.47
# NER R   83.22
# NER F   84.81
# SPEED   2549
#
#
# =============================== NER (per type) ===============================
#
#           P       R       F
# PER   86.47   83.22   84.81
#
# /usr/local/lib/python3.10/dist-packages/spacy/displacy/__init__.py:215: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# ✔ Generated 25 parses as HTML
# result

# %%
# !python -m spacy evaluate output/model-best data/val.spacy --gpu-id 0
# Out:
# 2023-06-28 12:29:30.684816: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   84.76
# NER R   82.97
# NER F   83.85
# SPEED   2447
#
#
# =============================== NER (per type) ===============================
#
#           P       R       F
# PER   84.76   82.97   83.85

# %% [markdown]
# # All Entity Considered

# %%
import json

# Open the JSON file
with open("/content/drive/MyDrive/NER/all_entity_merged_THREE_data.json", "r") as file:
    # Load the JSON data
    dataset = json.load(file)

len(dataset)
# Out:
# 18109

# %%
import random
from spacy.util import minibatch, compounding


# Set the random seed for reproducibility
random.seed(42)

# Shuffle the dataset
random.shuffle(dataset)

# Define the split ratios
train_ratio = 0.8  # 80% for training
val_ratio = 0.1  # 10% for validation
test_ratio = 0.1  # 10% for testing

# Calculate the sizes of each split
total_size = len(dataset)
train_size = int(train_ratio * total_size)
val_size = int(val_ratio * total_size)

# Split the dataset into train, validation, and test sets
train_data = dataset[:train_size]
val_data = dataset[train_size:train_size + val_size]
test_data = dataset[train_size + val_size:]

# Print the sizes of each split
print(f"Training set size: {len(train_data)}")
print(f"Validation set size: {len(val_data)}")
print(f"Test set size: {len(test_data)}")
# Out:
# Training set size: 14487
# Validation set size: 1810
# Test set size: 1812

# %%
import os
# !mkdir "all_data"

# %%
with open("all_data/train.json", 'w') as fp:
        json.dump(train_data, fp, indent=2, ensure_ascii=False)


with open("all_data/test.json", 'w') as fp:
        json.dump(test_data, fp, indent=2, ensure_ascii=False)


with open("all_data/val.json", 'w') as fp:
        json.dump(val_data, fp, indent=2, ensure_ascii=False)

# %%
# !python -m spacy convert all_data/train.json ./all_data
# !python -m spacy convert all_data/test.json ./all_data
# !python -m spacy convert all_data/val.json ./all_data
# Out:
# 2023-06-28 12:48:00.623210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Generated output file (14487 documents): all_data/train.spacy
# 2023-06-28 12:48:22.721112: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Generated output file (1812 documents): all_data/test.spacy
# 2023-06-28 12:48:31.909600: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Generated output file (1810 documents): all_data/val.spacy

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# 2023-06-28 12:50:15.969889: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./all_output --paths.train all_data/train.spacy --paths.dev all_data/val.spacy --gpu-id 0
# Out:
# 2023-06-28 12:50:35.118582: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Created output directory: all_output
# ℹ Saving to output directory: all_output
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2023-06-28 12:50:40,062] [INFO] Set up nlp object from config
# [2023-06-28 12:50:40,088] [INFO] Pipeline: ['transformer', 'ner']
# [2023-06-28 12:50:40,094] [INFO] Created vocabulary
# [2023-06-28 12:50:40,094] [INFO] Finished initializing nlp object
# ...
# Some weights of the model checkpoint at sagorsarker/bangla-bert-base were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# ...

# %%
# !zip -r onlyperson_entity.zip output/model-best

# %%
# !python -m spacy evaluate all_output//model-best all_data/val.spacy --gpu-id 0
# Out:
# 2023-06-28 14:33:20.545814: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   81.62
# NER R   75.94
# NER F   78.68
# SPEED   2749
#
#
# =============================== NER (per type) ===============================
#
#            P       R       F
# PER    83.85   77.82   80.72
# M      71.43   58.20   64.14
# LOC    87.25   85.31   86.27
# ORG    76.30   68.03   71.93
# GPE    53.85   50.40   52.07
# DATE   77.97   71.88   74.80
# LAW    37.50   37.50   37.50

# %%
# !python -m spacy evaluate all_output//model-best all_data/test.spacy --gpu-id 0
# Out:
# 2023-06-28 14:33:54.640375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# NER P   82.35
# NER R   76.38
# NER F   79.25
# SPEED   2663
#
#
# =============================== NER (per type) ===============================
#
#            P       R       F
# GPE    50.00   52.54   51.24
# LOC    87.79   81.87   84.73
# ORG    77.91   68.90   73.13
# PER    83.54   81.73   82.62
# DATE   64.52   62.50   63.49
# M      82.20   60.15   69.47
# LAW    60.00   37.50   46.15
